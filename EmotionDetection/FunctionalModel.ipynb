# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagar-Puniyani/EmotionDetection/blob/main/EmotionDetection/FunctionalModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Single Input Multiple Output

# %%
from keras.models import Model
from keras.layers import *

# %%
x = Input(shape=(3,))

# %%
hidden1 = Dense(128,activation='relu')(x)
hidden2 = Dense(64,activation='relu')(hidden1)

output1 = Dense(1,activation='linear')(hidden2)
output2 = Dense(1,activation='sigmoid')(hidden2)

# %%
model = Model(inputs= x, outputs=[output1 ,output2])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 3)]                  0         []
#
#  dense (Dense)               (None, 128)                  512       ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    65        ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    65        ['dense_1[0][0]']
#
# ...
# Total params: 8898 (34.76 KB)
# Trainable params: 8898 (34.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model

plot_model(model,show_shapes=True)

# %% [markdown]
# ## Multiple input and Single Output

# %%
inputA = Input(shape=(32,))
inputB = Input(shape=(128,))

# %%
x = Dense(8, activation='relu')(inputA)
x1 = Dense(4, activation='relu')(x)

# %%
y = Dense(64, activation='relu')(inputB)
y1 = Dense(32, activation='relu')(y)
y2 = Dense(4, activation='relu')(y1)

# %%
combine = concatenate([x1,y2])

# %%
z = Dense(2,activation='relu')(combine)
z1 = Dense(1,activation='relu')(z)

# %%
model1  = Model(inputs=[x,y] , outputs=z1)

# %%
model1.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_7 (InputLayer)        [(None, 64)]                 0         []
#
#  input_6 (InputLayer)        [(None, 8)]                  0         []
#
#  dense_7 (Dense)             (None, 32)                   2080      ['input_7[0][0]']
#
#  dense_5 (Dense)             (None, 4)                    36        ['input_6[0][0]']
#
#  dense_8 (Dense)             (None, 4)                    132       ['dense_7[2][0]']
#
#  concatenate (Concatenate)   (None, 8)                    0         ['dense_5[2][0]',
#                                                                      'dense_8[2][0]']
#
#  dense_9 (Dense)             (None, 2)                    18        ['concatenate[2][0]']
#
#  dense_10 (Dense)            (None, 1)                    3         ['dense_9[2][0]']
#
# ...

# %%
plot_model(model1 , show_shapes=True)
